# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('E:/Data Science/Projects/DataVisualization/Data/square-feet_and_house-price.csv')

# %%
data.head()
# Out:
#    square-feet  house-price
# 0          0.0     2.101102
# 1        200.0     2.252875
# 2        400.0     2.188469
# 3        600.0     1.802943
# 4        800.0     3.082641

# %%
data.isnull().any()
# Out:
# square-feet    False
# house-price    False
# dtype: bool

# %%
data.duplicated().any()
# Out:
# False

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))
fig.suptitle('Сharts of Thermostatic Rebates in USD', fontsize=16)

plt.subplot(2, 2, 1)
sns.scatterplot(x = 'square-feet', y = 'house-price', data = data)
plt.title('Square Feet vs House Price(in Millons)')

plt.subplot(2, 2, 2)
plt.plot(data['square-feet'], data['house-price'])
plt.title('Square Feet vs House Price(in Millons)')

plt.show()
